# %% [markdown]
# # Import everything and load source images

# %%
from core import *
from utils import *

img0 = load_image('disney.jpg')
img1 = load_image('nyc.jpg')
img2 = load_image('mustang.jpg')

# %% [markdown]
# # Display source images

# %%
display_image(img0, img1, img2)

# %% [markdown]
# # Apply algorithm

# %% [markdown]
# Let's try reducing the size of the first image, which is the disneyland castle.

# %%
out0 = down_size(img0, 100, 50)
display_image(img0, out0)

# %% [markdown]
# Now reduce the NYC skyline by a more aggressive amount of widths!

# %%
out1 = down_size(img1, 250, 0)
display_image(img1, out1)

# %% [markdown]
# The mustang image (be careful: this takes a long time!):

# %%
out2 = down_size(img2, 250, 100)
display_image(img2, out2)
